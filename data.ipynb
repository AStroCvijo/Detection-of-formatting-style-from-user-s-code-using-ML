# %%
import os
import shutil
import re
import json
from tqdm import tqdm
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer
from pygments import lex
from pygments.lexers import CppLexer
from pygments.token import Token

# %%
# Function for extracting c++ files
def filter_cpp_files(input_folder, output_folder):
    # List of C++ file extensions to filter
    cpp_extensions = ['.cpp', '.hpp', '.h', '.cc', '.cxx']

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through all files in the input folder
    for root, _, files in os.walk(input_folder):
        for file in files:
            # Check if the file has a C++ extension
            if any(file.endswith(ext) for ext in cpp_extensions):
                # Full path to the input file
                input_file_path = os.path.join(root, file)
                # Full path to the output file
                output_file_path = os.path.join(output_folder, file)
                # Copy the file to the output folder
                shutil.copy(input_file_path, output_file_path)
                print(f"Copied: {input_file_path} -> {output_file_path}")

# %%
# Extract cpp files from a given folder
input_folder = "data/leveldb-main"
output_folder = "data/cpp_files"
filter_cpp_files(input_folder, output_folder)
# Out:
# Copied: data/leveldb-main\benchmarks\db_bench.cc -> data/cpp_files\db_bench.cc
# Copied: data/leveldb-main\benchmarks\db_bench_log.cc -> data/cpp_files\db_bench_log.cc
# Copied: data/leveldb-main\benchmarks\db_bench_sqlite3.cc -> data/cpp_files\db_bench_sqlite3.cc
# Copied: data/leveldb-main\benchmarks\db_bench_tree_db.cc -> data/cpp_files\db_bench_tree_db.cc
# Copied: data/leveldb-main\db\autocompact_test.cc -> data/cpp_files\autocompact_test.cc
# Copied: data/leveldb-main\db\builder.cc -> data/cpp_files\builder.cc
# Copied: data/leveldb-main\db\builder.h -> data/cpp_files\builder.h
# Copied: data/leveldb-main\db\c.cc -> data/cpp_files\c.cc
# Copied: data/leveldb-main\db\corruption_test.cc -> data/cpp_files\corruption_test.cc
# Copied: data/leveldb-main\db\dbformat.cc -> data/cpp_files\dbformat.cc
# Copied: data/leveldb-main\db\dbformat.h -> data/cpp_files\dbformat.h
# Copied: data/leveldb-main\db\dbformat_test.cc -> data/cpp_files\dbformat_test.cc
# Copied: data/leveldb-main\db\db_impl.cc -> data/cpp_files\db_impl.cc
# Copied: data/leveldb-main\db\db_impl.h -> data/cpp_files\db_impl.h
# Copied: data/leveldb-main\db\db_iter.cc -> data/cpp_files\db_iter.cc
# Copied: data/leveldb-main\db\db_iter.h -> data/cpp_files\db_iter.h
# Copied: data/leveldb-main\db\db_test.cc -> data/cpp_files\db_test.cc
# Copied: data/leveldb-main\db\dumpfile.cc -> data/cpp_files\dumpfile.cc
# Copied: data/leveldb-main\db\fault_injection_test.cc -> data/cpp_files\fault_injection_test.cc
# Copied: data/leveldb-main\db\filename.cc -> data/cpp_files\filename.cc
# Copied: data/leveldb-main\db\filename.h -> data/cpp_files\filename.h
# Copied: data/leveldb-main\db\filename_test.cc -> data/cpp_files\filename_test.cc
# Copied: data/leveldb-main\db\leveldbutil.cc -> data/cpp_files\leveldbutil.cc
# Copied: data/leveldb-main\db\log_format.h -> data/cpp_files\log_format.h
# Copied: data/leveldb-main\db\log_reader.cc -> data/cpp_files\log_reader.cc
# Copied: data/leveldb-main\db\log_reader.h -> data/cpp_files\log_reader.h
# Copied: data/leveldb-main\db\log_test.cc -> data/cpp_files\log_test.cc
# Copied: data/leveldb-main\db\log_writer.cc -> data/cpp_files\log_writer.cc
# Copied: data/leveldb-main\db\log_writer.h -> data/cpp_files\log_writer.h
# Copied: data/leveldb-main\db\memtable.cc -> data/cpp_files\memtable.cc
# Copied: data/leveldb-main\db\memtable.h -> data/cpp_files\memtable.h
# Copied: data/leveldb-main\db\recovery_test.cc -> data/cpp_files\recovery_test.cc
# Copied: data/leveldb-main\db\repair.cc -> data/cpp_files\repair.cc
# Copied: data/leveldb-main\db\skiplist.h -> data/cpp_files\skiplist.h
# Copied: data/leveldb-main\db\skiplist_test.cc -> data/cpp_files\skiplist_test.cc
# Copied: data/leveldb-main\db\snapshot.h -> data/cpp_files\snapshot.h
# Copied: data/leveldb-main\db\table_cache.cc -> data/cpp_files\table_cache.cc
# Copied: data/leveldb-main\db\table_cache.h -> data/cpp_files\table_cache.h
# Copied: data/leveldb-main\db\version_edit.cc -> data/cpp_files\version_edit.cc
# Copied: data/leveldb-main\db\version_edit.h -> data/cpp_files\version_edit.h
# Copied: data/leveldb-main\db\version_edit_test.cc -> data/cpp_files\version_edit_test.cc
# Copied: data/leveldb-main\db\version_set.cc -> data/cpp_files\version_set.cc
# Copied: data/leveldb-main\db\version_set.h -> data/cpp_files\version_set.h
# Copied: data/leveldb-main\db\version_set_test.cc -> data/cpp_files\version_set_test.cc
# Copied: data/leveldb-main\db\write_batch.cc -> data/cpp_files\write_batch.cc
# Copied: data/leveldb-main\db\write_batch_internal.h -> data/cpp_files\write_batch_internal.h
# Copied: data/leveldb-main\db\write_batch_test.cc -> data/cpp_files\write_batch_test.cc
# Copied: data/leveldb-main\helpers\memenv\memenv.cc -> data/cpp_files\memenv.cc
# Copied: data/leveldb-main\helpers\memenv\memenv.h -> data/cpp_files\memenv.h
# Copied: data/leveldb-main\helpers\memenv\memenv_test.cc -> data/cpp_files\memenv_test.cc
# Copied: data/leveldb-main\include\leveldb\c.h -> data/cpp_files\c.h
# Copied: data/leveldb-main\include\leveldb\cache.h -> data/cpp_files\cache.h
# Copied: data/leveldb-main\include\leveldb\comparator.h -> data/cpp_files\comparator.h
# Copied: data/leveldb-main\include\leveldb\db.h -> data/cpp_files\db.h
# Copied: data/leveldb-main\include\leveldb\dumpfile.h -> data/cpp_files\dumpfile.h
# Copied: data/leveldb-main\include\leveldb\env.h -> data/cpp_files\env.h
# Copied: data/leveldb-main\include\leveldb\export.h -> data/cpp_files\export.h
# Copied: data/leveldb-main\include\leveldb\filter_policy.h -> data/cpp_files\filter_policy.h
# Copied: data/leveldb-main\include\leveldb\iterator.h -> data/cpp_files\iterator.h
# Copied: data/leveldb-main\include\leveldb\options.h -> data/cpp_files\options.h
# Copied: data/leveldb-main\include\leveldb\slice.h -> data/cpp_files\slice.h
# Copied: data/leveldb-main\include\leveldb\status.h -> data/cpp_files\status.h
# Copied: data/leveldb-main\include\leveldb\table.h -> data/cpp_files\table.h
# Copied: data/leveldb-main\include\leveldb\table_builder.h -> data/cpp_files\table_builder.h
# Copied: data/leveldb-main\include\leveldb\write_batch.h -> data/cpp_files\write_batch.h
# Copied: data/leveldb-main\issues\issue178_test.cc -> data/cpp_files\issue178_test.cc
# Copied: data/leveldb-main\issues\issue200_test.cc -> data/cpp_files\issue200_test.cc
# Copied: data/leveldb-main\issues\issue320_test.cc -> data/cpp_files\issue320_test.cc
# Copied: data/leveldb-main\port\port.h -> data/cpp_files\port.h
# Copied: data/leveldb-main\port\port_example.h -> data/cpp_files\port_example.h
# Copied: data/leveldb-main\port\port_stdcxx.h -> data/cpp_files\port_stdcxx.h
# Copied: data/leveldb-main\port\thread_annotations.h -> data/cpp_files\thread_annotations.h
# Copied: data/leveldb-main\table\block.cc -> data/cpp_files\block.cc
# Copied: data/leveldb-main\table\block.h -> data/cpp_files\block.h
# Copied: data/leveldb-main\table\block_builder.cc -> data/cpp_files\block_builder.cc
# Copied: data/leveldb-main\table\block_builder.h -> data/cpp_files\block_builder.h
# Copied: data/leveldb-main\table\filter_block.cc -> data/cpp_files\filter_block.cc
# Copied: data/leveldb-main\table\filter_block.h -> data/cpp_files\filter_block.h
# Copied: data/leveldb-main\table\filter_block_test.cc -> data/cpp_files\filter_block_test.cc
# Copied: data/leveldb-main\table\format.cc -> data/cpp_files\format.cc
# Copied: data/leveldb-main\table\format.h -> data/cpp_files\format.h
# Copied: data/leveldb-main\table\iterator.cc -> data/cpp_files\iterator.cc
# Copied: data/leveldb-main\table\iterator_wrapper.h -> data/cpp_files\iterator_wrapper.h
# Copied: data/leveldb-main\table\merger.cc -> data/cpp_files\merger.cc
# Copied: data/leveldb-main\table\merger.h -> data/cpp_files\merger.h
# Copied: data/leveldb-main\table\table.cc -> data/cpp_files\table.cc
# Copied: data/leveldb-main\table\table_builder.cc -> data/cpp_files\table_builder.cc
# Copied: data/leveldb-main\table\table_test.cc -> data/cpp_files\table_test.cc
# Copied: data/leveldb-main\table\two_level_iterator.cc -> data/cpp_files\two_level_iterator.cc
# Copied: data/leveldb-main\table\two_level_iterator.h -> data/cpp_files\two_level_iterator.h
# Copied: data/leveldb-main\util\arena.cc -> data/cpp_files\arena.cc
# Copied: data/leveldb-main\util\arena.h -> data/cpp_files\arena.h
# Copied: data/leveldb-main\util\arena_test.cc -> data/cpp_files\arena_test.cc
# Copied: data/leveldb-main\util\bloom.cc -> data/cpp_files\bloom.cc
# Copied: data/leveldb-main\util\bloom_test.cc -> data/cpp_files\bloom_test.cc
# Copied: data/leveldb-main\util\cache.cc -> data/cpp_files\cache.cc
# Copied: data/leveldb-main\util\cache_test.cc -> data/cpp_files\cache_test.cc
# Copied: data/leveldb-main\util\coding.cc -> data/cpp_files\coding.cc
# Copied: data/leveldb-main\util\coding.h -> data/cpp_files\coding.h
# Copied: data/leveldb-main\util\coding_test.cc -> data/cpp_files\coding_test.cc
# Copied: data/leveldb-main\util\comparator.cc -> data/cpp_files\comparator.cc
# Copied: data/leveldb-main\util\crc32c.cc -> data/cpp_files\crc32c.cc
# Copied: data/leveldb-main\util\crc32c.h -> data/cpp_files\crc32c.h
# Copied: data/leveldb-main\util\crc32c_test.cc -> data/cpp_files\crc32c_test.cc
# Copied: data/leveldb-main\util\env.cc -> data/cpp_files\env.cc
# Copied: data/leveldb-main\util\env_posix.cc -> data/cpp_files\env_posix.cc
# Copied: data/leveldb-main\util\env_posix_test.cc -> data/cpp_files\env_posix_test.cc
# Copied: data/leveldb-main\util\env_posix_test_helper.h -> data/cpp_files\env_posix_test_helper.h
# Copied: data/leveldb-main\util\env_test.cc -> data/cpp_files\env_test.cc
# Copied: data/leveldb-main\util\env_windows.cc -> data/cpp_files\env_windows.cc
# Copied: data/leveldb-main\util\env_windows_test.cc -> data/cpp_files\env_windows_test.cc
# Copied: data/leveldb-main\util\env_windows_test_helper.h -> data/cpp_files\env_windows_test_helper.h
# Copied: data/leveldb-main\util\filter_policy.cc -> data/cpp_files\filter_policy.cc
# Copied: data/leveldb-main\util\hash.cc -> data/cpp_files\hash.cc
# Copied: data/leveldb-main\util\hash.h -> data/cpp_files\hash.h
# Copied: data/leveldb-main\util\hash_test.cc -> data/cpp_files\hash_test.cc
# Copied: data/leveldb-main\util\histogram.cc -> data/cpp_files\histogram.cc
# Copied: data/leveldb-main\util\histogram.h -> data/cpp_files\histogram.h
# Copied: data/leveldb-main\util\logging.cc -> data/cpp_files\logging.cc
# Copied: data/leveldb-main\util\logging.h -> data/cpp_files\logging.h
# Copied: data/leveldb-main\util\logging_test.cc -> data/cpp_files\logging_test.cc
# Copied: data/leveldb-main\util\mutexlock.h -> data/cpp_files\mutexlock.h
# Copied: data/leveldb-main\util\no_destructor.h -> data/cpp_files\no_destructor.h
# Copied: data/leveldb-main\util\no_destructor_test.cc -> data/cpp_files\no_destructor_test.cc
# Copied: data/leveldb-main\util\options.cc -> data/cpp_files\options.cc
# Copied: data/leveldb-main\util\posix_logger.h -> data/cpp_files\posix_logger.h
# Copied: data/leveldb-main\util\random.h -> data/cpp_files\random.h
# Copied: data/leveldb-main\util\status.cc -> data/cpp_files\status.cc
# Copied: data/leveldb-main\util\status_test.cc -> data/cpp_files\status_test.cc
# Copied: data/leveldb-main\util\testutil.cc -> data/cpp_files\testutil.cc
# Copied: data/leveldb-main\util\testutil.h -> data/cpp_files\testutil.h
# Copied: data/leveldb-main\util\windows_logger.h -> data/cpp_files\windows_logger.h

# %%
import re

def tokenize_cpp_code(code):
    # Regular expressions for common C++ tokens
    token_pattern = re.compile(r'[a-zA-Z_][a-zA-Z0-9_]*|[{}()\[\];,.<>:=+-/*&|^%!~?]|"[^"]*"|\d+')
    
    tokens_with_spacing = []
    
    # Split the code by lines to capture newlines
    lines = code.splitlines(keepends=True)  # keepends=True to preserve newlines
    
    for line in lines:
        position = 0  # Track the position of the cursor in the line
        tokens = token_pattern.findall(line)

        for token in tokens:
            token_start = line.find(token, position)

            # Capture spacing before the token (whitespace)
            spacing = line[position:token_start]

            # Handle spacing: Add a space token for each space
            if spacing:
                for char in spacing:
                    if char == ' ':
                        tokens_with_spacing.append("<space>")  # Represent each space as <s-1>
                    elif char == '\t':
                        tokens_with_spacing.append("<space>")  # Optionally represent tabs as <s-1>
            
            # Add the token itself
            tokens_with_spacing.append(token)
            position = token_start + len(token)

        # Handle newlines at the end of the line
        if line.endswith("\n"):
            newline_count = line.count("\n")
            tokens_with_spacing.extend([f"<newline>"] * newline_count)  # Represent each newline as <n-1>

    return tokens_with_spacing

# %%
# Function to process a folder of C++ files
def preprocess_cpp_folder(folder_path, output_file):
    all_files_data = []
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".cpp") or file.endswith(".h"):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    code = f.read()
                    
                    # Tokenize the code and capture formatting
                    tokens_with_spacing = tokenize_cpp_code(code)
                    
                    # Serialize the tokens with spacing into a structured format (e.g., list of tokens)
                    all_files_data.append({
                        'file_name': file,
                        'tokens': tokens_with_spacing
                    })
    
    # Write the preprocessed data to an output file
    with open(output_file, 'w', encoding='utf-8') as out_f:
        for file_data in all_files_data:
            # Join tokens with a space between them
            output_line = ' '.join(file_data['tokens'])
            out_f.write(output_line + '\n')  # Add a newline after each file's tokens

# Example usage
if __name__ == "__main__":
    preprocess_cpp_folder('path/to/cpp/files', 'output.txt')

# %%
# PreProcess the data
folder_path = "data/cpp_files"
output_file = "data/preprocessed_cpp_data.txt"
preprocess_cpp_folder(folder_path, output_file)

print(f"Preprocessed C++ files saved to {output_file}")
# Out:
# Preprocessed C++ files saved to data/preprocessed_cpp_data.txt
