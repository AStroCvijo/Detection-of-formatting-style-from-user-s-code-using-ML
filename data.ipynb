# %%
import os
import shutil
import re
import json
from tqdm import tqdm
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer
from pygments import lex
from pygments.lexers import CppLexer
from pygments.token import Token

# %%
# Function for extracting c++ files
def filter_cpp_files(input_folder, output_folder):
    # List of C++ file extensions to filter
    cpp_extensions = ['.cpp', '.hpp', '.h', '.cc', '.cxx']

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through all files in the input folder
    for root, _, files in os.walk(input_folder):
        for file in files:
            # Check if the file has a C++ extension
            if any(file.endswith(ext) for ext in cpp_extensions):
                # Full path to the input file
                input_file_path = os.path.join(root, file)
                # Full path to the output file
                output_file_path = os.path.join(output_folder, file)
                # Copy the file to the output folder
                shutil.copy(input_file_path, output_file_path)
                print(f"Copied: {input_file_path} -> {output_file_path}")

# %%
# Extract cpp files from a given folder
input_folder = "data/leveldb-main"
output_folder = "data/cpp_files"
filter_cpp_files(input_folder, output_folder)
# Out:
# Copied: data/leveldb-main\benchmarks\db_bench.cc -> data/cpp_files\db_bench.cc
# Copied: data/leveldb-main\benchmarks\db_bench_log.cc -> data/cpp_files\db_bench_log.cc
# Copied: data/leveldb-main\benchmarks\db_bench_sqlite3.cc -> data/cpp_files\db_bench_sqlite3.cc
# Copied: data/leveldb-main\benchmarks\db_bench_tree_db.cc -> data/cpp_files\db_bench_tree_db.cc
# Copied: data/leveldb-main\db\autocompact_test.cc -> data/cpp_files\autocompact_test.cc
# Copied: data/leveldb-main\db\builder.cc -> data/cpp_files\builder.cc
# Copied: data/leveldb-main\db\builder.h -> data/cpp_files\builder.h
# Copied: data/leveldb-main\db\c.cc -> data/cpp_files\c.cc
# Copied: data/leveldb-main\db\corruption_test.cc -> data/cpp_files\corruption_test.cc
# Copied: data/leveldb-main\db\dbformat.cc -> data/cpp_files\dbformat.cc
# Copied: data/leveldb-main\db\dbformat.h -> data/cpp_files\dbformat.h
# Copied: data/leveldb-main\db\dbformat_test.cc -> data/cpp_files\dbformat_test.cc
# Copied: data/leveldb-main\db\db_impl.cc -> data/cpp_files\db_impl.cc
# Copied: data/leveldb-main\db\db_impl.h -> data/cpp_files\db_impl.h
# Copied: data/leveldb-main\db\db_iter.cc -> data/cpp_files\db_iter.cc
# Copied: data/leveldb-main\db\db_iter.h -> data/cpp_files\db_iter.h
# Copied: data/leveldb-main\db\db_test.cc -> data/cpp_files\db_test.cc
# Copied: data/leveldb-main\db\dumpfile.cc -> data/cpp_files\dumpfile.cc
# Copied: data/leveldb-main\db\fault_injection_test.cc -> data/cpp_files\fault_injection_test.cc
# Copied: data/leveldb-main\db\filename.cc -> data/cpp_files\filename.cc
# Copied: data/leveldb-main\db\filename.h -> data/cpp_files\filename.h
# Copied: data/leveldb-main\db\filename_test.cc -> data/cpp_files\filename_test.cc
# Copied: data/leveldb-main\db\leveldbutil.cc -> data/cpp_files\leveldbutil.cc
# Copied: data/leveldb-main\db\log_format.h -> data/cpp_files\log_format.h
# Copied: data/leveldb-main\db\log_reader.cc -> data/cpp_files\log_reader.cc
# Copied: data/leveldb-main\db\log_reader.h -> data/cpp_files\log_reader.h
# Copied: data/leveldb-main\db\log_test.cc -> data/cpp_files\log_test.cc
# Copied: data/leveldb-main\db\log_writer.cc -> data/cpp_files\log_writer.cc
# Copied: data/leveldb-main\db\log_writer.h -> data/cpp_files\log_writer.h
# Copied: data/leveldb-main\db\memtable.cc -> data/cpp_files\memtable.cc
# Copied: data/leveldb-main\db\memtable.h -> data/cpp_files\memtable.h
# Copied: data/leveldb-main\db\recovery_test.cc -> data/cpp_files\recovery_test.cc
# Copied: data/leveldb-main\db\repair.cc -> data/cpp_files\repair.cc
# Copied: data/leveldb-main\db\skiplist.h -> data/cpp_files\skiplist.h
# Copied: data/leveldb-main\db\skiplist_test.cc -> data/cpp_files\skiplist_test.cc
# Copied: data/leveldb-main\db\snapshot.h -> data/cpp_files\snapshot.h
# Copied: data/leveldb-main\db\table_cache.cc -> data/cpp_files\table_cache.cc
# Copied: data/leveldb-main\db\table_cache.h -> data/cpp_files\table_cache.h
# Copied: data/leveldb-main\db\version_edit.cc -> data/cpp_files\version_edit.cc
# Copied: data/leveldb-main\db\version_edit.h -> data/cpp_files\version_edit.h
# Copied: data/leveldb-main\db\version_edit_test.cc -> data/cpp_files\version_edit_test.cc
# Copied: data/leveldb-main\db\version_set.cc -> data/cpp_files\version_set.cc
# Copied: data/leveldb-main\db\version_set.h -> data/cpp_files\version_set.h
# Copied: data/leveldb-main\db\version_set_test.cc -> data/cpp_files\version_set_test.cc
# Copied: data/leveldb-main\db\write_batch.cc -> data/cpp_files\write_batch.cc
# Copied: data/leveldb-main\db\write_batch_internal.h -> data/cpp_files\write_batch_internal.h
# Copied: data/leveldb-main\db\write_batch_test.cc -> data/cpp_files\write_batch_test.cc
# Copied: data/leveldb-main\filament\android\common\CallbackUtils.cpp -> data/cpp_files\CallbackUtils.cpp
# Copied: data/leveldb-main\filament\android\common\CallbackUtils.h -> data/cpp_files\CallbackUtils.h
# Copied: data/leveldb-main\filament\android\common\NioUtils.cpp -> data/cpp_files\NioUtils.cpp
# Copied: data/leveldb-main\filament\android\common\NioUtils.h -> data/cpp_files\NioUtils.h
# Copied: data/leveldb-main\filament\android\filamat-android\src\main\cpp\MaterialBuilder.cpp -> data/cpp_files\MaterialBuilder.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\BufferObject.cpp -> data/cpp_files\BufferObject.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Camera.cpp -> data/cpp_files\Camera.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\ColorGrading.cpp -> data/cpp_files\ColorGrading.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Colors.cpp -> data/cpp_files\Colors.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Engine.cpp -> data/cpp_files\Engine.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\EntityManager.cpp -> data/cpp_files\EntityManager.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Fence.cpp -> data/cpp_files\Fence.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Filament.cpp -> data/cpp_files\Filament.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\IndexBuffer.cpp -> data/cpp_files\IndexBuffer.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\IndirectLight.cpp -> data/cpp_files\IndirectLight.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\LightManager.cpp -> data/cpp_files\LightManager.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Material.cpp -> data/cpp_files\Material.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\MaterialInstance.cpp -> data/cpp_files\MaterialInstance.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\MathUtils.cpp -> data/cpp_files\MathUtils.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\MorphTargetBuffer.cpp -> data/cpp_files\MorphTargetBuffer.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\NativeSurface.cpp -> data/cpp_files\NativeSurface.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\RenderableManager.cpp -> data/cpp_files\RenderableManager.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Renderer.cpp -> data/cpp_files\Renderer.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\RenderTarget.cpp -> data/cpp_files\RenderTarget.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Scene.cpp -> data/cpp_files\Scene.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\SkinningBuffer.cpp -> data/cpp_files\SkinningBuffer.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\SkyBox.cpp -> data/cpp_files\SkyBox.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Stream.cpp -> data/cpp_files\Stream.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\SurfaceOrientation.cpp -> data/cpp_files\SurfaceOrientation.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\SwapChain.cpp -> data/cpp_files\SwapChain.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\Texture.cpp -> data/cpp_files\Texture.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\TextureSampler.cpp -> data/cpp_files\TextureSampler.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\ToneMapper.cpp -> data/cpp_files\ToneMapper.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\TransformManager.cpp -> data/cpp_files\TransformManager.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\VertexBuffer.cpp -> data/cpp_files\VertexBuffer.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\View.cpp -> data/cpp_files\View.cpp
# Copied: data/leveldb-main\filament\android\filament-android\src\main\cpp\nativewindow\Android.cpp -> data/cpp_files\Android.cpp
# Copied: data/leveldb-main\filament\android\filament-utils-android\src\main\cpp\AutomationEngine.cpp -> data/cpp_files\AutomationEngine.cpp
# Copied: data/leveldb-main\filament\android\filament-utils-android\src\main\cpp\Bookmark.cpp -> data/cpp_files\Bookmark.cpp
# Copied: data/leveldb-main\filament\android\filament-utils-android\src\main\cpp\HDRLoader.cpp -> data/cpp_files\HDRLoader.cpp
# Copied: data/leveldb-main\filament\android\filament-utils-android\src\main\cpp\IBLPrefilterContext.cpp -> data/cpp_files\IBLPrefilterContext.cpp
# Copied: data/leveldb-main\filament\android\filament-utils-android\src\main\cpp\Manipulator.cpp -> data/cpp_files\Manipulator.cpp
# Copied: data/leveldb-main\filament\android\filament-utils-android\src\main\cpp\RemoteServer.cpp -> data/cpp_files\RemoteServer.cpp
# Copied: data/leveldb-main\filament\android\filament-utils-android\src\main\cpp\Utils.cpp -> data/cpp_files\Utils.cpp
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\Animator.cpp -> data/cpp_files\Animator.cpp
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\AssetLoader.cpp -> data/cpp_files\AssetLoader.cpp
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\FilamentAsset.cpp -> data/cpp_files\FilamentAsset.cpp
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\FilamentInstance.cpp -> data/cpp_files\FilamentInstance.cpp
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\MaterialKey.cpp -> data/cpp_files\MaterialKey.cpp
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\MaterialKey.h -> data/cpp_files\MaterialKey.h
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\ResourceLoader.cpp -> data/cpp_files\ResourceLoader.cpp
# Copied: data/leveldb-main\filament\android\gltfio-android\src\main\cpp\UbershaderProvider.cpp -> data/cpp_files\UbershaderProvider.cpp
# Copied: data/leveldb-main\filament\filament\backend\include\backend\AcquiredImage.h -> data/cpp_files\AcquiredImage.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\BufferDescriptor.h -> data/cpp_files\BufferDescriptor.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\CallbackHandler.h -> data/cpp_files\CallbackHandler.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\DescriptorSetOffsetArray.h -> data/cpp_files\DescriptorSetOffsetArray.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\DriverApiForward.h -> data/cpp_files\DriverApiForward.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\DriverEnums.h -> data/cpp_files\DriverEnums.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\Handle.h -> data/cpp_files\Handle.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\PipelineState.h -> data/cpp_files\PipelineState.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\PixelBufferDescriptor.h -> data/cpp_files\PixelBufferDescriptor.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\Platform.h -> data/cpp_files\Platform.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\PresentCallable.h -> data/cpp_files\PresentCallable.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\Program.h -> data/cpp_files\Program.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\SamplerDescriptor.h -> data/cpp_files\SamplerDescriptor.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\TargetBufferInfo.h -> data/cpp_files\TargetBufferInfo.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\OpenGLPlatform.h -> data/cpp_files\OpenGLPlatform.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformCocoaGL.h -> data/cpp_files\PlatformCocoaGL.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformCocoaTouchGL.h -> data/cpp_files\PlatformCocoaTouchGL.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformEGL.h -> data/cpp_files\PlatformEGL.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformEGLAndroid.h -> data/cpp_files\PlatformEGLAndroid.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformEGLHeadless.h -> data/cpp_files\PlatformEGLHeadless.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformGLX.h -> data/cpp_files\PlatformGLX.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformOSMesa.h -> data/cpp_files\PlatformOSMesa.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformWebGL.h -> data/cpp_files\PlatformWebGL.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\PlatformWGL.h -> data/cpp_files\PlatformWGL.h
# Copied: data/leveldb-main\filament\filament\backend\include\backend\platforms\VulkanPlatform.h -> data/cpp_files\VulkanPlatform.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\BackendUtils.h -> data/cpp_files\BackendUtils.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\CircularBuffer.h -> data/cpp_files\CircularBuffer.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\CommandBufferQueue.h -> data/cpp_files\CommandBufferQueue.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\CommandStream.h -> data/cpp_files\CommandStream.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\Dispatcher.h -> data/cpp_files\Dispatcher.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\Driver.h -> data/cpp_files\Driver.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\DriverApi.h -> data/cpp_files\DriverApi.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\HandleAllocator.h -> data/cpp_files\HandleAllocator.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\PlatformFactory.h -> data/cpp_files\PlatformFactory.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\SamplerGroup.h -> data/cpp_files\SamplerGroup.h
# Copied: data/leveldb-main\filament\filament\backend\include\private\backend\VirtualMachineEnv.h -> data/cpp_files\VirtualMachineEnv.h
# Copied: data/leveldb-main\filament\filament\backend\src\BackendUtils.cpp -> data/cpp_files\BackendUtils.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\BlobCacheKey.cpp -> data/cpp_files\BlobCacheKey.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\BlobCacheKey.h -> data/cpp_files\BlobCacheKey.h
# Copied: data/leveldb-main\filament\filament\backend\src\Callable.cpp -> data/cpp_files\Callable.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\CallbackManager.cpp -> data/cpp_files\CallbackManager.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\CallbackManager.h -> data/cpp_files\CallbackManager.h
# Copied: data/leveldb-main\filament\filament\backend\src\CircularBuffer.cpp -> data/cpp_files\CircularBuffer.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\CommandBufferQueue.cpp -> data/cpp_files\CommandBufferQueue.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\CommandStream.cpp -> data/cpp_files\CommandStream.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\CommandStreamDispatcher.h -> data/cpp_files\CommandStreamDispatcher.h
# Copied: data/leveldb-main\filament\filament\backend\src\CompilerThreadPool.cpp -> data/cpp_files\CompilerThreadPool.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\CompilerThreadPool.h -> data/cpp_files\CompilerThreadPool.h
# Copied: data/leveldb-main\filament\filament\backend\src\DataReshaper.h -> data/cpp_files\DataReshaper.h
# Copied: data/leveldb-main\filament\filament\backend\src\Driver.cpp -> data/cpp_files\Driver.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\DriverBase.h -> data/cpp_files\DriverBase.h
# Copied: data/leveldb-main\filament\filament\backend\src\Handle.cpp -> data/cpp_files\Handle.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\HandleAllocator.cpp -> data/cpp_files\HandleAllocator.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\ostream.cpp -> data/cpp_files\ostream.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\Platform.cpp -> data/cpp_files\Platform.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\PlatformFactory.cpp -> data/cpp_files\PlatformFactory.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\Program.cpp -> data/cpp_files\Program.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\SamplerGroup.cpp -> data/cpp_files\SamplerGroup.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\VirtualMachineEnv.cpp -> data/cpp_files\VirtualMachineEnv.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalBlitter.h -> data/cpp_files\MetalBlitter.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalBuffer.h -> data/cpp_files\MetalBuffer.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalBufferPool.h -> data/cpp_files\MetalBufferPool.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalContext.h -> data/cpp_files\MetalContext.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalDriver.h -> data/cpp_files\MetalDriver.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalDriverFactory.h -> data/cpp_files\MetalDriverFactory.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalEnums.h -> data/cpp_files\MetalEnums.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalExternalImage.h -> data/cpp_files\MetalExternalImage.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalHandles.h -> data/cpp_files\MetalHandles.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalPlatform.h -> data/cpp_files\MetalPlatform.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalResourceTracker.cpp -> data/cpp_files\MetalResourceTracker.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalResourceTracker.h -> data/cpp_files\MetalResourceTracker.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalShaderCompiler.h -> data/cpp_files\MetalShaderCompiler.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalState.h -> data/cpp_files\MetalState.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalTimerQuery.h -> data/cpp_files\MetalTimerQuery.h
# Copied: data/leveldb-main\filament\filament\backend\src\metal\MetalUtils.h -> data/cpp_files\MetalUtils.h
# Copied: data/leveldb-main\filament\filament\backend\src\noop\NoopDriver.cpp -> data/cpp_files\NoopDriver.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\noop\NoopDriver.h -> data/cpp_files\NoopDriver.h
# Copied: data/leveldb-main\filament\filament\backend\src\noop\PlatformNoop.cpp -> data/cpp_files\PlatformNoop.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\noop\PlatformNoop.h -> data/cpp_files\PlatformNoop.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\BindingMap.h -> data/cpp_files\BindingMap.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\GLBufferObject.h -> data/cpp_files\GLBufferObject.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\GLDescriptorSet.cpp -> data/cpp_files\GLDescriptorSet.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\GLDescriptorSet.h -> data/cpp_files\GLDescriptorSet.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\GLDescriptorSetLayout.h -> data/cpp_files\GLDescriptorSetLayout.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\GLTexture.h -> data/cpp_files\GLTexture.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\GLUtils.cpp -> data/cpp_files\GLUtils.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\GLUtils.h -> data/cpp_files\GLUtils.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\gl_headers.cpp -> data/cpp_files\gl_headers.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\gl_headers.h -> data/cpp_files\gl_headers.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\NullGLES.h -> data/cpp_files\NullGLES.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLBlobCache.cpp -> data/cpp_files\OpenGLBlobCache.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLBlobCache.h -> data/cpp_files\OpenGLBlobCache.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLContext.cpp -> data/cpp_files\OpenGLContext.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLContext.h -> data/cpp_files\OpenGLContext.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLDriver.cpp -> data/cpp_files\OpenGLDriver.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLDriver.h -> data/cpp_files\OpenGLDriver.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLDriverFactory.h -> data/cpp_files\OpenGLDriverFactory.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLPlatform.cpp -> data/cpp_files\OpenGLPlatform.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLProgram.cpp -> data/cpp_files\OpenGLProgram.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLProgram.h -> data/cpp_files\OpenGLProgram.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLTimerQuery.cpp -> data/cpp_files\OpenGLTimerQuery.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\OpenGLTimerQuery.h -> data/cpp_files\OpenGLTimerQuery.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\ShaderCompilerService.cpp -> data/cpp_files\ShaderCompilerService.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\ShaderCompilerService.h -> data/cpp_files\ShaderCompilerService.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\CocoaExternalImage.h -> data/cpp_files\CocoaExternalImage.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\CocoaTouchExternalImage.h -> data/cpp_files\CocoaTouchExternalImage.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\ExternalStreamManagerAndroid.cpp -> data/cpp_files\ExternalStreamManagerAndroid.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\ExternalStreamManagerAndroid.h -> data/cpp_files\ExternalStreamManagerAndroid.h
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\PlatformEGL.cpp -> data/cpp_files\PlatformEGL.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\PlatformEGLAndroid.cpp -> data/cpp_files\PlatformEGLAndroid.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\PlatformEGLHeadless.cpp -> data/cpp_files\PlatformEGLHeadless.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\PlatformGLX.cpp -> data/cpp_files\PlatformGLX.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\PlatformOSMesa.cpp -> data/cpp_files\PlatformOSMesa.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\PlatformWebGL.cpp -> data/cpp_files\PlatformWebGL.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\opengl\platforms\PlatformWGL.cpp -> data/cpp_files\PlatformWGL.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanBlitter.cpp -> data/cpp_files\VulkanBlitter.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanBlitter.h -> data/cpp_files\VulkanBlitter.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanBuffer.cpp -> data/cpp_files\VulkanBuffer.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanBuffer.h -> data/cpp_files\VulkanBuffer.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanCommands.cpp -> data/cpp_files\VulkanCommands.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanCommands.h -> data/cpp_files\VulkanCommands.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanConstants.h -> data/cpp_files\VulkanConstants.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanContext.cpp -> data/cpp_files\VulkanContext.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanContext.h -> data/cpp_files\VulkanContext.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanDriver.cpp -> data/cpp_files\VulkanDriver.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanDriver.h -> data/cpp_files\VulkanDriver.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanDriverFactory.h -> data/cpp_files\VulkanDriverFactory.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanFboCache.cpp -> data/cpp_files\VulkanFboCache.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanFboCache.h -> data/cpp_files\VulkanFboCache.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanHandles.cpp -> data/cpp_files\VulkanHandles.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanHandles.h -> data/cpp_files\VulkanHandles.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanImageUtility.cpp -> data/cpp_files\VulkanImageUtility.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanImageUtility.h -> data/cpp_files\VulkanImageUtility.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanMemory.cpp -> data/cpp_files\VulkanMemory.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanMemory.h -> data/cpp_files\VulkanMemory.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanPipelineCache.cpp -> data/cpp_files\VulkanPipelineCache.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanPipelineCache.h -> data/cpp_files\VulkanPipelineCache.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanReadPixels.cpp -> data/cpp_files\VulkanReadPixels.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanReadPixels.h -> data/cpp_files\VulkanReadPixels.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanResourceAllocator.h -> data/cpp_files\VulkanResourceAllocator.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanResources.cpp -> data/cpp_files\VulkanResources.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanResources.h -> data/cpp_files\VulkanResources.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanSamplerCache.cpp -> data/cpp_files\VulkanSamplerCache.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanSamplerCache.h -> data/cpp_files\VulkanSamplerCache.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanStagePool.cpp -> data/cpp_files\VulkanStagePool.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanStagePool.h -> data/cpp_files\VulkanStagePool.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanSwapChain.cpp -> data/cpp_files\VulkanSwapChain.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanSwapChain.h -> data/cpp_files\VulkanSwapChain.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanTexture.cpp -> data/cpp_files\VulkanTexture.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanTexture.h -> data/cpp_files\VulkanTexture.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanUtility.cpp -> data/cpp_files\VulkanUtility.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\VulkanUtility.h -> data/cpp_files\VulkanUtility.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\caching\VulkanDescriptorSetManager.cpp -> data/cpp_files\VulkanDescriptorSetManager.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\caching\VulkanDescriptorSetManager.h -> data/cpp_files\VulkanDescriptorSetManager.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\caching\VulkanPipelineLayoutCache.cpp -> data/cpp_files\VulkanPipelineLayoutCache.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\caching\VulkanPipelineLayoutCache.h -> data/cpp_files\VulkanPipelineLayoutCache.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\platform\VulkanPlatform.cpp -> data/cpp_files\VulkanPlatform.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\platform\VulkanPlatformAndroidLinuxWindows.cpp -> data/cpp_files\VulkanPlatformAndroidLinuxWindows.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\platform\VulkanPlatformSwapChainImpl.cpp -> data/cpp_files\VulkanPlatformSwapChainImpl.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\platform\VulkanPlatformSwapChainImpl.h -> data/cpp_files\VulkanPlatformSwapChainImpl.h
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\spirv\VulkanSpirvUtils.cpp -> data/cpp_files\VulkanSpirvUtils.cpp
# Copied: data/leveldb-main\filament\filament\backend\src\vulkan\spirv\VulkanSpirvUtils.h -> data/cpp_files\VulkanSpirvUtils.h
# Copied: data/leveldb-main\filament\filament\backend\test\Arguments.cpp -> data/cpp_files\Arguments.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\BackendTest.cpp -> data/cpp_files\BackendTest.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\BackendTest.h -> data/cpp_files\BackendTest.h
# Copied: data/leveldb-main\filament\filament\backend\test\BackendTestUtils.h -> data/cpp_files\BackendTestUtils.h
# Copied: data/leveldb-main\filament\filament\backend\test\builtinResource.h -> data/cpp_files\builtinResource.h
# Copied: data/leveldb-main\filament\filament\backend\test\ComputeTest.cpp -> data/cpp_files\ComputeTest.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\ComputeTest.h -> data/cpp_files\ComputeTest.h
# Copied: data/leveldb-main\filament\filament\backend\test\linux_runner.cpp -> data/cpp_files\linux_runner.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\PlatformRunner.h -> data/cpp_files\PlatformRunner.h
# Copied: data/leveldb-main\filament\filament\backend\test\ShaderGenerator.cpp -> data/cpp_files\ShaderGenerator.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\ShaderGenerator.h -> data/cpp_files\ShaderGenerator.h
# Copied: data/leveldb-main\filament\filament\backend\test\test_Blit.cpp -> data/cpp_files\test_Blit.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_BufferUpdates.cpp -> data/cpp_files\test_BufferUpdates.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_Callbacks.cpp -> data/cpp_files\test_Callbacks.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_ComputeBasic.cpp -> data/cpp_files\test_ComputeBasic.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_FeedbackLoops.cpp -> data/cpp_files\test_FeedbackLoops.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_Handles.cpp -> data/cpp_files\test_Handles.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_LoadImage.cpp -> data/cpp_files\test_LoadImage.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_MipLevels.cpp -> data/cpp_files\test_MipLevels.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_MissingRequiredAttributes.cpp -> data/cpp_files\test_MissingRequiredAttributes.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_MRT.cpp -> data/cpp_files\test_MRT.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_PushConstants.cpp -> data/cpp_files\test_PushConstants.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_ReadPixels.cpp -> data/cpp_files\test_ReadPixels.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_RenderExternalImage.cpp -> data/cpp_files\test_RenderExternalImage.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_Scissor.cpp -> data/cpp_files\test_Scissor.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\test_StencilBuffer.cpp -> data/cpp_files\test_StencilBuffer.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\TrianglePrimitive.cpp -> data/cpp_files\TrianglePrimitive.cpp
# Copied: data/leveldb-main\filament\filament\backend\test\TrianglePrimitive.h -> data/cpp_files\TrianglePrimitive.h
# Copied: data/leveldb-main\filament\filament\benchmark\benchmark_filament.cpp -> data/cpp_files\benchmark_filament.cpp
# Copied: data/leveldb-main\filament\filament\benchmark\PerformanceCounters.h -> data/cpp_files\PerformanceCounters.h
# Copied: data/leveldb-main\filament\filament\include\filament\Box.h -> data/cpp_files\Box.h
# Copied: data/leveldb-main\filament\filament\include\filament\BufferObject.h -> data/cpp_files\BufferObject.h
# Copied: data/leveldb-main\filament\filament\include\filament\Camera.h -> data/cpp_files\Camera.h
# Copied: data/leveldb-main\filament\filament\include\filament\Color.h -> data/cpp_files\Color.h
# Copied: data/leveldb-main\filament\filament\include\filament\ColorGrading.h -> data/cpp_files\ColorGrading.h
# Copied: data/leveldb-main\filament\filament\include\filament\ColorSpace.h -> data/cpp_files\ColorSpace.h
# Copied: data/leveldb-main\filament\filament\include\filament\DebugRegistry.h -> data/cpp_files\DebugRegistry.h
# Copied: data/leveldb-main\filament\filament\include\filament\Engine.h -> data/cpp_files\Engine.h
# Copied: data/leveldb-main\filament\filament\include\filament\Exposure.h -> data/cpp_files\Exposure.h
# Copied: data/leveldb-main\filament\filament\include\filament\Fence.h -> data/cpp_files\Fence.h
# Copied: data/leveldb-main\filament\filament\include\filament\FilamentAPI.h -> data/cpp_files\FilamentAPI.h
# Copied: data/leveldb-main\filament\filament\include\filament\Frustum.h -> data/cpp_files\Frustum.h
# Copied: data/leveldb-main\filament\filament\include\filament\IndexBuffer.h -> data/cpp_files\IndexBuffer.h
# Copied: data/leveldb-main\filament\filament\include\filament\IndirectLight.h -> data/cpp_files\IndirectLight.h
# Copied: data/leveldb-main\filament\filament\include\filament\InstanceBuffer.h -> data/cpp_files\InstanceBuffer.h
# Copied: data/leveldb-main\filament\filament\include\filament\LightManager.h -> data/cpp_files\LightManager.h
# Copied: data/leveldb-main\filament\filament\include\filament\Material.h -> data/cpp_files\Material.h
# Copied: data/leveldb-main\filament\filament\include\filament\MaterialInstance.h -> data/cpp_files\MaterialInstance.h
# Copied: data/leveldb-main\filament\filament\include\filament\MorphTargetBuffer.h -> data/cpp_files\MorphTargetBuffer.h
# Copied: data/leveldb-main\filament\filament\include\filament\Options.h -> data/cpp_files\Options.h
# Copied: data/leveldb-main\filament\filament\include\filament\RenderableManager.h -> data/cpp_files\RenderableManager.h
# Copied: data/leveldb-main\filament\filament\include\filament\Renderer.h -> data/cpp_files\Renderer.h
# Copied: data/leveldb-main\filament\filament\include\filament\RenderTarget.h -> data/cpp_files\RenderTarget.h
# Copied: data/leveldb-main\filament\filament\include\filament\Scene.h -> data/cpp_files\Scene.h
# Copied: data/leveldb-main\filament\filament\include\filament\SkinningBuffer.h -> data/cpp_files\SkinningBuffer.h
# Copied: data/leveldb-main\filament\filament\include\filament\Skybox.h -> data/cpp_files\Skybox.h
# Copied: data/leveldb-main\filament\filament\include\filament\Stream.h -> data/cpp_files\Stream.h
# Copied: data/leveldb-main\filament\filament\include\filament\SwapChain.h -> data/cpp_files\SwapChain.h
# Copied: data/leveldb-main\filament\filament\include\filament\Texture.h -> data/cpp_files\Texture.h
# Copied: data/leveldb-main\filament\filament\include\filament\TextureSampler.h -> data/cpp_files\TextureSampler.h
# Copied: data/leveldb-main\filament\filament\include\filament\ToneMapper.h -> data/cpp_files\ToneMapper.h
# Copied: data/leveldb-main\filament\filament\include\filament\TransformManager.h -> data/cpp_files\TransformManager.h
# Copied: data/leveldb-main\filament\filament\include\filament\VertexBuffer.h -> data/cpp_files\VertexBuffer.h
# Copied: data/leveldb-main\filament\filament\include\filament\View.h -> data/cpp_files\View.h
# Copied: data/leveldb-main\filament\filament\include\filament\Viewport.h -> data/cpp_files\Viewport.h
# Copied: data/leveldb-main\filament\filament\src\Allocators.h -> data/cpp_files\Allocators.h
# Copied: data/leveldb-main\filament\filament\src\AtlasAllocator.cpp -> data/cpp_files\AtlasAllocator.cpp
# Copied: data/leveldb-main\filament\filament\src\AtlasAllocator.h -> data/cpp_files\AtlasAllocator.h
# Copied: data/leveldb-main\filament\filament\src\Bimap.h -> data/cpp_files\Bimap.h
# Copied: data/leveldb-main\filament\filament\src\BufferObject.cpp -> data/cpp_files\BufferObject.cpp
# Copied: data/leveldb-main\filament\filament\src\BufferPoolAllocator.h -> data/cpp_files\BufferPoolAllocator.h
# Copied: data/leveldb-main\filament\filament\src\Camera.cpp -> data/cpp_files\Camera.cpp
# Copied: data/leveldb-main\filament\filament\src\Color.cpp -> data/cpp_files\Color.cpp
# Copied: data/leveldb-main\filament\filament\src\ColorSpaceUtils.cpp -> data/cpp_files\ColorSpaceUtils.cpp
# Copied: data/leveldb-main\filament\filament\src\ColorSpaceUtils.h -> data/cpp_files\ColorSpaceUtils.h
# Copied: data/leveldb-main\filament\filament\src\Culler.cpp -> data/cpp_files\Culler.cpp
# Copied: data/leveldb-main\filament\filament\src\Culler.h -> data/cpp_files\Culler.h
# Copied: data/leveldb-main\filament\filament\src\DebugRegistry.cpp -> data/cpp_files\DebugRegistry.cpp
# Copied: data/leveldb-main\filament\filament\src\DFG.cpp -> data/cpp_files\DFG.cpp
# Copied: data/leveldb-main\filament\filament\src\DFG.h -> data/cpp_files\DFG.h
# Copied: data/leveldb-main\filament\filament\src\downcast.h -> data/cpp_files\downcast.h
# Copied: data/leveldb-main\filament\filament\src\Engine.cpp -> data/cpp_files\Engine.cpp
# Copied: data/leveldb-main\filament\filament\src\Exposure.cpp -> data/cpp_files\Exposure.cpp
# Copied: data/leveldb-main\filament\filament\src\Fence.cpp -> data/cpp_files\Fence.cpp
# Copied: data/leveldb-main\filament\filament\src\FilamentAPI-impl.h -> data/cpp_files\FilamentAPI-impl.h
# Copied: data/leveldb-main\filament\filament\src\FilamentBuilder.cpp -> data/cpp_files\FilamentBuilder.cpp
# Copied: data/leveldb-main\filament\filament\src\FrameHistory.h -> data/cpp_files\FrameHistory.h
# Copied: data/leveldb-main\filament\filament\src\FrameInfo.cpp -> data/cpp_files\FrameInfo.cpp
# Copied: data/leveldb-main\filament\filament\src\FrameInfo.h -> data/cpp_files\FrameInfo.h
# Copied: data/leveldb-main\filament\filament\src\FrameSkipper.cpp -> data/cpp_files\FrameSkipper.cpp
# Copied: data/leveldb-main\filament\filament\src\FrameSkipper.h -> data/cpp_files\FrameSkipper.h
# Copied: data/leveldb-main\filament\filament\src\Froxelizer.cpp -> data/cpp_files\Froxelizer.cpp
# Copied: data/leveldb-main\filament\filament\src\Froxelizer.h -> data/cpp_files\Froxelizer.h
# Copied: data/leveldb-main\filament\filament\src\Frustum.cpp -> data/cpp_files\Frustum.cpp
# Copied: data/leveldb-main\filament\filament\src\fsr.cpp -> data/cpp_files\fsr.cpp
# Copied: data/leveldb-main\filament\filament\src\fsr.h -> data/cpp_files\fsr.h
# Copied: data/leveldb-main\filament\filament\src\HwDescriptorSetLayoutFactory.cpp -> data/cpp_files\HwDescriptorSetLayoutFactory.cpp
# Copied: data/leveldb-main\filament\filament\src\HwDescriptorSetLayoutFactory.h -> data/cpp_files\HwDescriptorSetLayoutFactory.h
# Copied: data/leveldb-main\filament\filament\src\HwRenderPrimitiveFactory.cpp -> data/cpp_files\HwRenderPrimitiveFactory.cpp
# Copied: data/leveldb-main\filament\filament\src\HwRenderPrimitiveFactory.h -> data/cpp_files\HwRenderPrimitiveFactory.h
# Copied: data/leveldb-main\filament\filament\src\HwVertexBufferInfoFactory.cpp -> data/cpp_files\HwVertexBufferInfoFactory.cpp
# Copied: data/leveldb-main\filament\filament\src\HwVertexBufferInfoFactory.h -> data/cpp_files\HwVertexBufferInfoFactory.h
# Copied: data/leveldb-main\filament\filament\src\IndexBuffer.cpp -> data/cpp_files\IndexBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\IndirectLight.cpp -> data/cpp_files\IndirectLight.cpp
# Copied: data/leveldb-main\filament\filament\src\InstanceBuffer.cpp -> data/cpp_files\InstanceBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\Intersections.h -> data/cpp_files\Intersections.h
# Copied: data/leveldb-main\filament\filament\src\LightManager.cpp -> data/cpp_files\LightManager.cpp
# Copied: data/leveldb-main\filament\filament\src\Material.cpp -> data/cpp_files\Material.cpp
# Copied: data/leveldb-main\filament\filament\src\MaterialInstance.cpp -> data/cpp_files\MaterialInstance.cpp
# Copied: data/leveldb-main\filament\filament\src\MaterialParser.cpp -> data/cpp_files\MaterialParser.cpp
# Copied: data/leveldb-main\filament\filament\src\MaterialParser.h -> data/cpp_files\MaterialParser.h
# Copied: data/leveldb-main\filament\filament\src\MorphTargetBuffer.cpp -> data/cpp_files\MorphTargetBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\PIDController.h -> data/cpp_files\PIDController.h
# Copied: data/leveldb-main\filament\filament\src\PostProcessManager.cpp -> data/cpp_files\PostProcessManager.cpp
# Copied: data/leveldb-main\filament\filament\src\PostProcessManager.h -> data/cpp_files\PostProcessManager.h
# Copied: data/leveldb-main\filament\filament\src\RenderableManager.cpp -> data/cpp_files\RenderableManager.cpp
# Copied: data/leveldb-main\filament\filament\src\Renderer.cpp -> data/cpp_files\Renderer.cpp
# Copied: data/leveldb-main\filament\filament\src\RendererUtils.cpp -> data/cpp_files\RendererUtils.cpp
# Copied: data/leveldb-main\filament\filament\src\RendererUtils.h -> data/cpp_files\RendererUtils.h
# Copied: data/leveldb-main\filament\filament\src\RenderPass.cpp -> data/cpp_files\RenderPass.cpp
# Copied: data/leveldb-main\filament\filament\src\RenderPass.h -> data/cpp_files\RenderPass.h
# Copied: data/leveldb-main\filament\filament\src\RenderPrimitive.cpp -> data/cpp_files\RenderPrimitive.cpp
# Copied: data/leveldb-main\filament\filament\src\RenderPrimitive.h -> data/cpp_files\RenderPrimitive.h
# Copied: data/leveldb-main\filament\filament\src\RenderTarget.cpp -> data/cpp_files\RenderTarget.cpp
# Copied: data/leveldb-main\filament\filament\src\ResourceAllocator.cpp -> data/cpp_files\ResourceAllocator.cpp
# Copied: data/leveldb-main\filament\filament\src\ResourceAllocator.h -> data/cpp_files\ResourceAllocator.h
# Copied: data/leveldb-main\filament\filament\src\ResourceList.cpp -> data/cpp_files\ResourceList.cpp
# Copied: data/leveldb-main\filament\filament\src\ResourceList.h -> data/cpp_files\ResourceList.h
# Copied: data/leveldb-main\filament\filament\src\Scene.cpp -> data/cpp_files\Scene.cpp
# Copied: data/leveldb-main\filament\filament\src\ShadowMap.cpp -> data/cpp_files\ShadowMap.cpp
# Copied: data/leveldb-main\filament\filament\src\ShadowMap.h -> data/cpp_files\ShadowMap.h
# Copied: data/leveldb-main\filament\filament\src\ShadowMapManager.cpp -> data/cpp_files\ShadowMapManager.cpp
# Copied: data/leveldb-main\filament\filament\src\ShadowMapManager.h -> data/cpp_files\ShadowMapManager.h
# Copied: data/leveldb-main\filament\filament\src\SharedHandle.h -> data/cpp_files\SharedHandle.h
# Copied: data/leveldb-main\filament\filament\src\SkinningBuffer.cpp -> data/cpp_files\SkinningBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\Skybox.cpp -> data/cpp_files\Skybox.cpp
# Copied: data/leveldb-main\filament\filament\src\Stream.cpp -> data/cpp_files\Stream.cpp
# Copied: data/leveldb-main\filament\filament\src\SwapChain.cpp -> data/cpp_files\SwapChain.cpp
# Copied: data/leveldb-main\filament\filament\src\Texture.cpp -> data/cpp_files\Texture.cpp
# Copied: data/leveldb-main\filament\filament\src\ToneMapper.cpp -> data/cpp_files\ToneMapper.cpp
# Copied: data/leveldb-main\filament\filament\src\TransformManager.cpp -> data/cpp_files\TransformManager.cpp
# Copied: data/leveldb-main\filament\filament\src\TypedUniformBuffer.h -> data/cpp_files\TypedUniformBuffer.h
# Copied: data/leveldb-main\filament\filament\src\UniformBuffer.cpp -> data/cpp_files\UniformBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\UniformBuffer.h -> data/cpp_files\UniformBuffer.h
# Copied: data/leveldb-main\filament\filament\src\VertexBuffer.cpp -> data/cpp_files\VertexBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\View.cpp -> data/cpp_files\View.cpp
# Copied: data/leveldb-main\filament\filament\src\components\CameraManager.cpp -> data/cpp_files\CameraManager.cpp
# Copied: data/leveldb-main\filament\filament\src\components\CameraManager.h -> data/cpp_files\CameraManager.h
# Copied: data/leveldb-main\filament\filament\src\components\LightManager.cpp -> data/cpp_files\LightManager.cpp
# Copied: data/leveldb-main\filament\filament\src\components\LightManager.h -> data/cpp_files\LightManager.h
# Copied: data/leveldb-main\filament\filament\src\components\RenderableManager.cpp -> data/cpp_files\RenderableManager.cpp
# Copied: data/leveldb-main\filament\filament\src\components\RenderableManager.h -> data/cpp_files\RenderableManager.h
# Copied: data/leveldb-main\filament\filament\src\components\TransformManager.cpp -> data/cpp_files\TransformManager.cpp
# Copied: data/leveldb-main\filament\filament\src\components\TransformManager.h -> data/cpp_files\TransformManager.h
# Copied: data/leveldb-main\filament\filament\src\details\BufferObject.cpp -> data/cpp_files\BufferObject.cpp
# Copied: data/leveldb-main\filament\filament\src\details\BufferObject.h -> data/cpp_files\BufferObject.h
# Copied: data/leveldb-main\filament\filament\src\details\Camera.cpp -> data/cpp_files\Camera.cpp
# Copied: data/leveldb-main\filament\filament\src\details\Camera.h -> data/cpp_files\Camera.h
# Copied: data/leveldb-main\filament\filament\src\details\ColorGrading.cpp -> data/cpp_files\ColorGrading.cpp
# Copied: data/leveldb-main\filament\filament\src\details\ColorGrading.h -> data/cpp_files\ColorGrading.h
# Copied: data/leveldb-main\filament\filament\src\details\DebugRegistry.cpp -> data/cpp_files\DebugRegistry.cpp
# Copied: data/leveldb-main\filament\filament\src\details\DebugRegistry.h -> data/cpp_files\DebugRegistry.h
# Copied: data/leveldb-main\filament\filament\src\details\Engine.cpp -> data/cpp_files\Engine.cpp
# Copied: data/leveldb-main\filament\filament\src\details\Engine.h -> data/cpp_files\Engine.h
# Copied: data/leveldb-main\filament\filament\src\details\Fence.cpp -> data/cpp_files\Fence.cpp
# Copied: data/leveldb-main\filament\filament\src\details\Fence.h -> data/cpp_files\Fence.h
# Copied: data/leveldb-main\filament\filament\src\details\IndexBuffer.cpp -> data/cpp_files\IndexBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\details\IndexBuffer.h -> data/cpp_files\IndexBuffer.h
# Copied: data/leveldb-main\filament\filament\src\details\IndirectLight.cpp -> data/cpp_files\IndirectLight.cpp
# Copied: data/leveldb-main\filament\filament\src\details\IndirectLight.h -> data/cpp_files\IndirectLight.h
# Copied: data/leveldb-main\filament\filament\src\details\InstanceBuffer.cpp -> data/cpp_files\InstanceBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\details\InstanceBuffer.h -> data/cpp_files\InstanceBuffer.h
# Copied: data/leveldb-main\filament\filament\src\details\Material.cpp -> data/cpp_files\Material.cpp
# Copied: data/leveldb-main\filament\filament\src\details\Material.h -> data/cpp_files\Material.h
# Copied: data/leveldb-main\filament\filament\src\details\MaterialInstance.cpp -> data/cpp_files\MaterialInstance.cpp
# Copied: data/leveldb-main\filament\filament\src\details\MaterialInstance.h -> data/cpp_files\MaterialInstance.h
# Copied: data/leveldb-main\filament\filament\src\details\MorphTargetBuffer.cpp -> data/cpp_files\MorphTargetBuffer.cpp
# Copied: data/leveldb-main\filament\filament\src\details\MorphTargetBuffer.h -> data/cpp_files\MorphTargetBuffer.h
# Copied: data/leveldb-main\filament\filament\src\details\Renderer.cpp -> data/cpp_files\Renderer.cpp
# ...
# Copied: data/leveldb-main\googletest\googletest\samples\sample4.cc -> data/cpp_files\sample4.cc
# Copied: data/leveldb-main\googletest\googletest\samples\sample4.h -> data/cpp_files\sample4.h
# Copied: data/leveldb-main\googletest\googletest\samples\sample4_unittest.cc -> data/cpp_files\sample4_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\samples\sample5_unittest.cc -> data/cpp_files\sample5_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\samples\sample6_unittest.cc -> data/cpp_files\sample6_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\samples\sample7_unittest.cc -> data/cpp_files\sample7_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\samples\sample8_unittest.cc -> data/cpp_files\sample8_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\samples\sample9_unittest.cc -> data/cpp_files\sample9_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-all.cc -> data/cpp_files\gtest-all.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-assertion-result.cc -> data/cpp_files\gtest-assertion-result.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-death-test.cc -> data/cpp_files\gtest-death-test.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-filepath.cc -> data/cpp_files\gtest-filepath.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-internal-inl.h -> data/cpp_files\gtest-internal-inl.h
# Copied: data/leveldb-main\googletest\googletest\src\gtest-matchers.cc -> data/cpp_files\gtest-matchers.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-port.cc -> data/cpp_files\gtest-port.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-printers.cc -> data/cpp_files\gtest-printers.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-test-part.cc -> data/cpp_files\gtest-test-part.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest-typed-test.cc -> data/cpp_files\gtest-typed-test.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest.cc -> data/cpp_files\gtest.cc
# Copied: data/leveldb-main\googletest\googletest\src\gtest_main.cc -> data/cpp_files\gtest_main.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-break-on-failure-unittest_.cc -> data/cpp_files\googletest-break-on-failure-unittest_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-catch-exceptions-test_.cc -> data/cpp_files\googletest-catch-exceptions-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-color-test_.cc -> data/cpp_files\googletest-color-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-death-test-test.cc -> data/cpp_files\googletest-death-test-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-death-test_ex_test.cc -> data/cpp_files\googletest-death-test_ex_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-env-var-test_.cc -> data/cpp_files\googletest-env-var-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-failfast-unittest_.cc -> data/cpp_files\googletest-failfast-unittest_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-filepath-test.cc -> data/cpp_files\googletest-filepath-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-filter-unittest_.cc -> data/cpp_files\googletest-filter-unittest_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-global-environment-unittest_.cc -> data/cpp_files\googletest-global-environment-unittest_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-list-tests-unittest_.cc -> data/cpp_files\googletest-list-tests-unittest_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-listener-test.cc -> data/cpp_files\googletest-listener-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-message-test.cc -> data/cpp_files\googletest-message-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-options-test.cc -> data/cpp_files\googletest-options-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-output-test_.cc -> data/cpp_files\googletest-output-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-param-test-invalid-name1-test_.cc -> data/cpp_files\googletest-param-test-invalid-name1-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-param-test-invalid-name2-test_.cc -> data/cpp_files\googletest-param-test-invalid-name2-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-param-test-test.cc -> data/cpp_files\googletest-param-test-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-param-test-test.h -> data/cpp_files\googletest-param-test-test.h
# Copied: data/leveldb-main\googletest\googletest\test\googletest-param-test2-test.cc -> data/cpp_files\googletest-param-test2-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-port-test.cc -> data/cpp_files\googletest-port-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-printers-test.cc -> data/cpp_files\googletest-printers-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-setuptestsuite-test_.cc -> data/cpp_files\googletest-setuptestsuite-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-shuffle-test_.cc -> data/cpp_files\googletest-shuffle-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-test-part-test.cc -> data/cpp_files\googletest-test-part-test.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-throw-on-failure-test_.cc -> data/cpp_files\googletest-throw-on-failure-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\googletest-uninitialized-test_.cc -> data/cpp_files\googletest-uninitialized-test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest-typed-test2_test.cc -> data/cpp_files\gtest-typed-test2_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest-typed-test_test.cc -> data/cpp_files\gtest-typed-test_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest-typed-test_test.h -> data/cpp_files\gtest-typed-test_test.h
# Copied: data/leveldb-main\googletest\googletest\test\gtest-unittest-api_test.cc -> data/cpp_files\gtest-unittest-api_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_all_test.cc -> data/cpp_files\gtest_all_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_assert_by_exception_test.cc -> data/cpp_files\gtest_assert_by_exception_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_dirs_test.cc -> data/cpp_files\gtest_dirs_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_environment_test.cc -> data/cpp_files\gtest_environment_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_help_test_.cc -> data/cpp_files\gtest_help_test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_list_output_unittest_.cc -> data/cpp_files\gtest_list_output_unittest_.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_main_unittest.cc -> data/cpp_files\gtest_main_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_no_test_unittest.cc -> data/cpp_files\gtest_no_test_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_pred_impl_unittest.cc -> data/cpp_files\gtest_pred_impl_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_premature_exit_test.cc -> data/cpp_files\gtest_premature_exit_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_prod_test.cc -> data/cpp_files\gtest_prod_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_repeat_test.cc -> data/cpp_files\gtest_repeat_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_skip_in_environment_setup_test.cc -> data/cpp_files\gtest_skip_in_environment_setup_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_skip_test.cc -> data/cpp_files\gtest_skip_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_sole_header_test.cc -> data/cpp_files\gtest_sole_header_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_stress_test.cc -> data/cpp_files\gtest_stress_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_testbridge_test_.cc -> data/cpp_files\gtest_testbridge_test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_test_macro_stack_footprint_test.cc -> data/cpp_files\gtest_test_macro_stack_footprint_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_throw_on_failure_ex_test.cc -> data/cpp_files\gtest_throw_on_failure_ex_test.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_unittest.cc -> data/cpp_files\gtest_unittest.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_xml_outfile1_test_.cc -> data/cpp_files\gtest_xml_outfile1_test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_xml_outfile2_test_.cc -> data/cpp_files\gtest_xml_outfile2_test_.cc
# Copied: data/leveldb-main\googletest\googletest\test\gtest_xml_output_unittest_.cc -> data/cpp_files\gtest_xml_output_unittest_.cc
# Copied: data/leveldb-main\googletest\googletest\test\production.cc -> data/cpp_files\production.cc
# Copied: data/leveldb-main\googletest\googletest\test\production.h -> data/cpp_files\production.h
# Copied: data/leveldb-main\helpers\memenv\memenv.cc -> data/cpp_files\memenv.cc
# Copied: data/leveldb-main\helpers\memenv\memenv.h -> data/cpp_files\memenv.h
# Copied: data/leveldb-main\helpers\memenv\memenv_test.cc -> data/cpp_files\memenv_test.cc
# Copied: data/leveldb-main\include\leveldb\c.h -> data/cpp_files\c.h
# Copied: data/leveldb-main\include\leveldb\cache.h -> data/cpp_files\cache.h
# Copied: data/leveldb-main\include\leveldb\comparator.h -> data/cpp_files\comparator.h
# Copied: data/leveldb-main\include\leveldb\db.h -> data/cpp_files\db.h
# Copied: data/leveldb-main\include\leveldb\dumpfile.h -> data/cpp_files\dumpfile.h
# Copied: data/leveldb-main\include\leveldb\env.h -> data/cpp_files\env.h
# Copied: data/leveldb-main\include\leveldb\export.h -> data/cpp_files\export.h
# Copied: data/leveldb-main\include\leveldb\filter_policy.h -> data/cpp_files\filter_policy.h
# Copied: data/leveldb-main\include\leveldb\iterator.h -> data/cpp_files\iterator.h
# Copied: data/leveldb-main\include\leveldb\options.h -> data/cpp_files\options.h
# Copied: data/leveldb-main\include\leveldb\slice.h -> data/cpp_files\slice.h
# Copied: data/leveldb-main\include\leveldb\status.h -> data/cpp_files\status.h
# Copied: data/leveldb-main\include\leveldb\table.h -> data/cpp_files\table.h
# Copied: data/leveldb-main\include\leveldb\table_builder.h -> data/cpp_files\table_builder.h
# Copied: data/leveldb-main\include\leveldb\write_batch.h -> data/cpp_files\write_batch.h
# Copied: data/leveldb-main\issues\issue178_test.cc -> data/cpp_files\issue178_test.cc
# Copied: data/leveldb-main\issues\issue200_test.cc -> data/cpp_files\issue200_test.cc
# Copied: data/leveldb-main\issues\issue320_test.cc -> data/cpp_files\issue320_test.cc
# Copied: data/leveldb-main\port\port.h -> data/cpp_files\port.h
# Copied: data/leveldb-main\port\port_example.h -> data/cpp_files\port_example.h
# Copied: data/leveldb-main\port\port_stdcxx.h -> data/cpp_files\port_stdcxx.h
# Copied: data/leveldb-main\port\thread_annotations.h -> data/cpp_files\thread_annotations.h
# Copied: data/leveldb-main\table\block.cc -> data/cpp_files\block.cc
# Copied: data/leveldb-main\table\block.h -> data/cpp_files\block.h
# Copied: data/leveldb-main\table\block_builder.cc -> data/cpp_files\block_builder.cc
# Copied: data/leveldb-main\table\block_builder.h -> data/cpp_files\block_builder.h
# Copied: data/leveldb-main\table\filter_block.cc -> data/cpp_files\filter_block.cc
# Copied: data/leveldb-main\table\filter_block.h -> data/cpp_files\filter_block.h
# Copied: data/leveldb-main\table\filter_block_test.cc -> data/cpp_files\filter_block_test.cc
# Copied: data/leveldb-main\table\format.cc -> data/cpp_files\format.cc
# Copied: data/leveldb-main\table\format.h -> data/cpp_files\format.h
# Copied: data/leveldb-main\table\iterator.cc -> data/cpp_files\iterator.cc
# Copied: data/leveldb-main\table\iterator_wrapper.h -> data/cpp_files\iterator_wrapper.h
# Copied: data/leveldb-main\table\merger.cc -> data/cpp_files\merger.cc
# Copied: data/leveldb-main\table\merger.h -> data/cpp_files\merger.h
# Copied: data/leveldb-main\table\table.cc -> data/cpp_files\table.cc
# Copied: data/leveldb-main\table\table_builder.cc -> data/cpp_files\table_builder.cc
# Copied: data/leveldb-main\table\table_test.cc -> data/cpp_files\table_test.cc
# Copied: data/leveldb-main\table\two_level_iterator.cc -> data/cpp_files\two_level_iterator.cc
# Copied: data/leveldb-main\table\two_level_iterator.h -> data/cpp_files\two_level_iterator.h
# Copied: data/leveldb-main\util\arena.cc -> data/cpp_files\arena.cc
# Copied: data/leveldb-main\util\arena.h -> data/cpp_files\arena.h
# Copied: data/leveldb-main\util\arena_test.cc -> data/cpp_files\arena_test.cc
# Copied: data/leveldb-main\util\bloom.cc -> data/cpp_files\bloom.cc
# Copied: data/leveldb-main\util\bloom_test.cc -> data/cpp_files\bloom_test.cc
# Copied: data/leveldb-main\util\cache.cc -> data/cpp_files\cache.cc
# Copied: data/leveldb-main\util\cache_test.cc -> data/cpp_files\cache_test.cc
# Copied: data/leveldb-main\util\coding.cc -> data/cpp_files\coding.cc
# Copied: data/leveldb-main\util\coding.h -> data/cpp_files\coding.h
# Copied: data/leveldb-main\util\coding_test.cc -> data/cpp_files\coding_test.cc
# Copied: data/leveldb-main\util\comparator.cc -> data/cpp_files\comparator.cc
# Copied: data/leveldb-main\util\crc32c.cc -> data/cpp_files\crc32c.cc
# Copied: data/leveldb-main\util\crc32c.h -> data/cpp_files\crc32c.h
# Copied: data/leveldb-main\util\crc32c_test.cc -> data/cpp_files\crc32c_test.cc
# Copied: data/leveldb-main\util\env.cc -> data/cpp_files\env.cc
# Copied: data/leveldb-main\util\env_posix.cc -> data/cpp_files\env_posix.cc
# Copied: data/leveldb-main\util\env_posix_test.cc -> data/cpp_files\env_posix_test.cc
# Copied: data/leveldb-main\util\env_posix_test_helper.h -> data/cpp_files\env_posix_test_helper.h
# Copied: data/leveldb-main\util\env_test.cc -> data/cpp_files\env_test.cc
# Copied: data/leveldb-main\util\env_windows.cc -> data/cpp_files\env_windows.cc
# Copied: data/leveldb-main\util\env_windows_test.cc -> data/cpp_files\env_windows_test.cc
# Copied: data/leveldb-main\util\env_windows_test_helper.h -> data/cpp_files\env_windows_test_helper.h
# Copied: data/leveldb-main\util\filter_policy.cc -> data/cpp_files\filter_policy.cc
# Copied: data/leveldb-main\util\hash.cc -> data/cpp_files\hash.cc
# Copied: data/leveldb-main\util\hash.h -> data/cpp_files\hash.h
# Copied: data/leveldb-main\util\hash_test.cc -> data/cpp_files\hash_test.cc
# Copied: data/leveldb-main\util\histogram.cc -> data/cpp_files\histogram.cc
# Copied: data/leveldb-main\util\histogram.h -> data/cpp_files\histogram.h
# Copied: data/leveldb-main\util\logging.cc -> data/cpp_files\logging.cc
# Copied: data/leveldb-main\util\logging.h -> data/cpp_files\logging.h
# Copied: data/leveldb-main\util\logging_test.cc -> data/cpp_files\logging_test.cc
# Copied: data/leveldb-main\util\mutexlock.h -> data/cpp_files\mutexlock.h
# Copied: data/leveldb-main\util\no_destructor.h -> data/cpp_files\no_destructor.h
# Copied: data/leveldb-main\util\no_destructor_test.cc -> data/cpp_files\no_destructor_test.cc
# Copied: data/leveldb-main\util\options.cc -> data/cpp_files\options.cc
# Copied: data/leveldb-main\util\posix_logger.h -> data/cpp_files\posix_logger.h
# Copied: data/leveldb-main\util\random.h -> data/cpp_files\random.h
# Copied: data/leveldb-main\util\status.cc -> data/cpp_files\status.cc
# Copied: data/leveldb-main\util\status_test.cc -> data/cpp_files\status_test.cc
# Copied: data/leveldb-main\util\testutil.cc -> data/cpp_files\testutil.cc
# Copied: data/leveldb-main\util\testutil.h -> data/cpp_files\testutil.h
# Copied: data/leveldb-main\util\windows_logger.h -> data/cpp_files\windows_logger.h

# %%
import re

def tokenize_cpp_code(code):
    # Regular expressions for common C++ tokens
    token_pattern = re.compile(r'[a-zA-Z_][a-zA-Z0-9_]*|[{}()\[\];,.<>:=+-/*&|^%!~?]|"[^"]*"|\d+')
    
    tokens_with_spacing = []
    
    # Split the code by lines to capture newlines
    lines = code.splitlines(keepends=True)  # keepends=True to preserve newlines
    
    for line in lines:
        position = 0  # Track the position of the cursor in the line
        tokens = token_pattern.findall(line)

        for token in tokens:
            token_start = line.find(token, position)

            # Capture spacing before the token (whitespace)
            spacing = line[position:token_start]

            # Handle spacing: Add a space token for each space
            if spacing:
                for char in spacing:
                    if char == ' ':
                        tokens_with_spacing.append("<space>")  # Represent each space as <s-1>
                    elif char == '\t':
                        tokens_with_spacing.append("<space>")  # Optionally represent tabs as <s-1>
            
            # Add the token itself
            tokens_with_spacing.append(token)
            position = token_start + len(token)

        # Handle newlines at the end of the line
        if line.endswith("\n"):
            newline_count = line.count("\n")
            tokens_with_spacing.extend([f"<newline>"] * newline_count)  # Represent each newline as <n-1>

    return tokens_with_spacing

# %%
# Function to process a folder of C++ files
def preprocess_cpp_folder(folder_path, output_file):
    all_files_data = []
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".cpp") or file.endswith(".h"):
                file_path = os.path.join(root, file)
                # Open with UTF-8 but ignore errors
                with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                    code = f.read()
                    
                    # Tokenize the code and capture formatting
                    tokens_with_spacing = tokenize_cpp_code(code)
                    
                    # Serialize the tokens with spacing into a structured format (e.g., list of tokens)
                    all_files_data.append({
                        'file_name': file,
                        'tokens': tokens_with_spacing
                    })
    
    # Write the preprocessed data to an output file
    with open(output_file, 'w', encoding='utf-8') as out_f:
        for file_data in all_files_data:
            # Join tokens with a space between them
            output_line = ' '.join(file_data['tokens'])
            out_f.write(output_line + '\n')  # Add a newline after each file's tokens

# %%
# PreProcess the data
folder_path = "data/cpp_files"
output_file = "data/preprocessed_cpp_data.txt"
preprocess_cpp_folder(folder_path, output_file)

print(f"Preprocessed C++ files saved to {output_file}")
# Out:
# Preprocessed C++ files saved to data/preprocessed_cpp_data.txt
